# %%
# notebook pour transformer les variables en distributions normales

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from pathlib import Path

# %%
raw = pd.read_csv('/Users/phuongnguyen/Documents/cours_BGD_Telecom_Paris_2024/Kit_Big_Data/dataset/nutrition_raw.csv')
raw.head()
# Out:
#    calories  total_fat_%  sugar_%  sodium_%  protein_%  sat_fat_%  carbs_%  \
# 0      51.5          0.0     13.0       0.0        2.0        0.0      4.0
# 1     173.4         18.0      0.0      17.0       22.0       35.0      1.0
# 2     269.8         22.0     32.0      48.0       39.0       27.0      5.0
# 3     368.1         17.0     10.0       2.0       14.0        8.0     20.0
# 4     352.9          1.0    337.0      23.0        3.0        0.0     28.0
#
#        id
# 0  137739
# 1   31490
# 2  112140
# 3   59389
# 4   44061

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231637 entries, 0 to 231636
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   calories     231637 non-null  float64
#  1   total_fat_%  231637 non-null  float64
#  2   sugar_%      231637 non-null  float64
#  3   sodium_%     231637 non-null  float64
#  4   protein_%    231637 non-null  float64
#  5   sat_fat_%    231637 non-null  float64
#  6   carbs_%      231637 non-null  float64
#  7   id           231637 non-null  int64
# dtypes: float64(7), int64(1)
# memory usage: 14.1 MB

# %%
for i, col in enumerate(raw.columns):
    fig, ax = plt.subplots()
    ax.hist(raw[col])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
zscore_data = scaler.fit_transform(raw['calories'].values.reshape(-1, 1))

print(zscore_data)
# Out:
# [[-0.35508052]
#  [-0.25261848]
#  [-0.17159024]
#  ...
#  [-0.34860835]
#  [-0.24034656]
#  [-0.25135766]]
